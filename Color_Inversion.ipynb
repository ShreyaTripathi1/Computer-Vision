# %%
import cv2
import matplotlib.pyplot as plt

#reads image as RGB
img = cv2.imread(r'C:\Users\User\Downloads\cv\trial.jpg')

plt.imshow(img)

# %%
img2= cv2.cvtColor(img2, cv2.COLOR_BGR2RGB) 
plt.imshow(img2)

# %%
# Converts BGR to YCrCb color space
img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2YCrCb)

# Displays the image
plt.imshow(cv2.cvtColor(img3, cv2.COLOR_YCrCb2RGB))  # Convert YCrCb to RGB for correct display
plt.show()

# %%
img3 = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
plt.imshow(img3)

# %%
img3 = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
plt.imshow(img3)

# %%
img4 = cv2.imread(r'C:\Users\User\Downloads\cv\trial.jpg')

# Convert the image to grayscale before applying Laplacian
gray_img4 = cv2.cvtColor(img4, cv2.COLOR_BGR2GRAY)
plt.imshow(img4)


# Apply Laplacian edge detection
laplacian = cv2.Laplacian(gray_img4, cv2.CV_64F)

# Show the edge-detected image using OpenCV
cv2.imshow('EdgeMap image', laplacian)

# Show the original image using Matplotlib
plt.imshow(cv2.cvtColor(img4, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB
plt.show()


laplacian = cv2. Laplacian (img4, cv2.CV_64F)
cv2.imshow('EdgeMap image', laplacian)
plt.imshow(img4)

#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
plt.imshow(img, cmap = 'hot')

# %%
plt.imshow(img, cmap ='nipy_spectral')
